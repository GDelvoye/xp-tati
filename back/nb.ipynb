# %%
from back.words_manager import load_pickle_list_of_words
import random as rd

# %%
def get_random_word_in_list_of_words_and_pop(list_of_words: list[str]):
    random_index = rd.randint(0, len(list_of_words)-1)
    chosen_word = list_of_words[random_index]
    list_of_words.pop(random_index)
    return chosen_word


def ask_if_already_seen() -> bool:
    answer = input("Already seen ? YN")
    while answer not in ["Y", "y", "N", "n"]:
        print("I do not understood you.")
        answer = input("Already seen ? YN")
    if answer in ["Y", "y"]:
        return True
    return False

# %%
class Word:
    def __init__(self, word, difficulty):
        self.word: str = word
        self.difficulty: int = difficulty
    def __repr__(self):
        return f"{self.word}, {self.difficulty}"

# %%
class Experiment:
    def __init__(self, difficulty: int):
        self.difficulty = difficulty
        self.turn: int = 0
        self.pool_of_seen_words: list[Word] = []
        self.pool_of_unseen_words: list[str] = load_pickle_list_of_words()

    def update_pool_of_seen_words_difficulty(self, difficulty_modifier: int):
        for word in self.pool_of_seen_words:
            word.difficulty += difficulty_modifier
    
    def choose_next_word(self) -> Word:
        for word in self.pool_of_seen_words:
            if word.difficulty == 0:
                self.pool_of_seen_words.remove(word)
                return word
        next_word = get_random_word_in_list_of_words_and_pop(self.pool_of_unseen_words)
        self.pool_of_seen_words.append(Word(next_word, self.difficulty))
        return Word(next_word, self.difficulty)
        

    def next_turn(self):
        print(f"Tour {self.turn}. Diff {self.difficulty}")
        self.update_pool_of_seen_words_difficulty(-1)
        for word in self.pool_of_seen_words:
            print(word)
        chosen_word = self.choose_next_word()
        print("###############################################")
        print(f"##########: {chosen_word}")
        print("###############################################")
        answer = ask_if_already_seen()
        if chosen_word.difficulty == 0:
            self.update_pool_of_seen_words_difficulty(1)
            if answer:
                self.difficulty+=1
            else:
                self.difficulty -= 1


        self.turn += 1
    
    def play(self, n_turn: int):
        for i in range(0, n_turn):
            self.next_turn()

# %%
ex = Experiment(3)
ex.play(20)
# Out:
# Tour 0. Diff 3
# ###############################################
# ##########: SAUCISSES, 3
# ###############################################
# Tour 1. Diff 3
# SAUCISSES, 2
# ###############################################
# ##########: CAUTERISES, 3
# ###############################################
# Tour 2. Diff 3
# SAUCISSES, 1
# CAUTERISES, 2
# ###############################################
# ##########: FONCERONT, 3
# ###############################################
# Tour 3. Diff 3
# SAUCISSES, 0
# CAUTERISES, 1
# FONCERONT, 2
# ###############################################
# ##########: SAUCISSES, 0
# ###############################################
# Tour 4. Diff 4
# CAUTERISES, 1
# FONCERONT, 2
# ###############################################
# ##########: CABLER, 4
# ###############################################
# Tour 5. Diff 4
# CAUTERISES, 0
# FONCERONT, 1
# CABLER, 3
# ###############################################
# ##########: CAUTERISES, 0
# ###############################################
# I do not understood you.
# Tour 6. Diff 5
# FONCERONT, 1
# CABLER, 3
# ###############################################
# ##########: LEADER, 5
# ###############################################
# Tour 7. Diff 5
# FONCERONT, 0
# CABLER, 2
# LEADER, 4
# ###############################################
# ##########: FONCERONT, 0
# ###############################################
# Tour 8. Diff 6
# CABLER, 2
# LEADER, 4
# ###############################################
# ##########: DOUTEZ, 6
# ###############################################
# Tour 9. Diff 6
# CABLER, 1
# LEADER, 3
# DOUTEZ, 5
# ###############################################
# ##########: RELAXERONT, 6
# ###############################################
# Tour 10. Diff 6
# CABLER, 0
# LEADER, 2
# DOUTEZ, 4
# RELAXERONT, 5
# ###############################################
# ##########: CABLER, 0
# ###############################################
# Tour 11. Diff 7
# LEADER, 2
# DOUTEZ, 4
# RELAXERONT, 5
# ###############################################
# ##########: GIRL, 7
# ###############################################
# Tour 12. Diff 7
# LEADER, 1
# DOUTEZ, 3
# RELAXERONT, 4
# GIRL, 6
# ###############################################
# ##########: ORCHESTRAIENT, 7
# ###############################################
# Tour 13. Diff 7
# LEADER, 0
# DOUTEZ, 2
# RELAXERONT, 3
# GIRL, 5
# ORCHESTRAIENT, 6
# ###############################################
# ##########: LEADER, 0
# ###############################################
# Tour 14. Diff 8
# DOUTEZ, 2
# RELAXERONT, 3
# GIRL, 5
# ORCHESTRAIENT, 6
# ###############################################
# ##########: OBLIGIEZ, 8
# ###############################################
# Tour 15. Diff 8
# DOUTEZ, 1
# RELAXERONT, 2
# GIRL, 4
# ORCHESTRAIENT, 5
# OBLIGIEZ, 7
# ###############################################
# ##########: TAISAIT, 8
# ###############################################
# Tour 16. Diff 8
# DOUTEZ, 0
# RELAXERONT, 1
# GIRL, 3
# ORCHESTRAIENT, 4
# OBLIGIEZ, 6
# TAISAIT, 7
# ###############################################
# ##########: DOUTEZ, 0
# ###############################################
# Tour 17. Diff 9
# RELAXERONT, 1
# GIRL, 3
# ORCHESTRAIENT, 4
# OBLIGIEZ, 6
# TAISAIT, 7
# ###############################################
# ##########: RONDELET, 9
# ###############################################
# Tour 18. Diff 9
# RELAXERONT, 0
# GIRL, 2
# ORCHESTRAIENT, 3
# OBLIGIEZ, 5
# TAISAIT, 6
# RONDELET, 8
# ###############################################
# ##########: RELAXERONT, 0
# ###############################################
# I do not understood you.
